# %% [markdown]
# <a href="https://colab.research.google.com/github/1021114Carlos/cfa_practice/blob/main/level_1/cfa_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, Math

# %%
#pricing a bond
bond_price = display(Math(r"P_b = \frac{c_1}{(1 + r)^T} + \frac{(c_2 + FV)}{(1 + r)^{t+1}}"))
# Out:
# $\displaystyle P_b = \frac{c_1}{(1 + r)^T} + \frac{(c_2 + FV)}{(1 + r)^{t+1}}$

# %%
print("Capital Asset Pricing Model (CAPM)\n")
display(Math(r"E(R_i) = R_f + \beta_i(E(R_m) - R_f)"))
# Out:
# Capital Asset Pricing Model (CAPM)
# $\displaystyle E(R_i) = R_f + \beta_i(E(R_m) - R_f)$

# %%
# Find expected return of stock.
beta = 1.2
rfr = 3/100
mkt_return = 10/100

expect_return = rfr + beta*(mkt_return - rfr)
expect_return
# Out:
# 0.114

# %%
r = [0.10, 0.05, -0.02, 0.12, 0.08]
num = 1
mult = 1
for ind in r:
  num += ind
  mult *= num
geo_mean = mult**(1/5) - 1
print(geo_mean)
# Out:
# 0.18901169028368248

# %%
balance = 12343.04
pay = balance/(204.39*12)
print(f"Pay off student loan balance in {pay:.4f} years")
# Out:
# Pay off student loan balance in 5.0325 years

# %%
year_pay = 204.39*12
year_pay
# Out:
# 2452.68

# %%
# NPV
npv_x = (40/(1.1) + 40/(1.1)**2 + 40/(1.1)**3 + 40/(1.1)**4)
npv_x

npv_y = (20/(1.1) + 30/(1.1)**2 + 50/(1.1)**3 + 60/(1.1)**4)
npv_y
# Out:
# 121.52175397855333

# %%
# Gordon Growth Model (Dividend Discount Model)
d1 = 2*(1 + 0.05)
stock = d1/(0.1 - 0.05)
stock
# Out:
# 42.0

# %%
# Duration and convexity with basis points
8.5*(-0.01) + (0.5*120*(-0.01)**2)
# Out:
# -0.079

# %%
# WACC
wacc = (.40/.60)*(.12) + (.40/100)*(.08)*(1 - .25)
wacc
# Out:
# 0.08024

# %%
# Sharp ratio
sp = (.12-.03)/.15
sp
# Out:
# 0.6
