# %% [markdown]
# <a href="https://colab.research.google.com/github/1021114Carlos/cfa_practice/blob/main/level_1/fixed_income.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
coupon_bond = 2.5/100
par_value = 100000
n = 2
coupon_payment = (par_value*coupon_bond)/2
print(f"Coupon payments made semiannually ${coupon_payment:.4f}")
# Out:
# Coupon payments made semiannually $1250.0000

# %%
# Determine Floating rate note (FRN) coupon and interest payable
frn = 10**7
bps = 125/10000
quarterly = 1/4
mrr = -0.50% # market reference rate
# Out:
# 0.0125
