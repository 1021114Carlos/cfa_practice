# %% [markdown]
# <a href="https://colab.research.google.com/github/1021114Carlos/cfa_practice/blob/main/level_1/Alternative_Investment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from IPython.display import display, Math, Latex

# %%
# gp = general parter rate of return
# cu = catch-up contributions
# h  = hurdle rate
# r  = rate
gp_rate_return = display(Math(r"r_{gp} = max \cdot [0, r_{cu} + p \cdot (r - r_h - r_{cu})]"))
# Out:
# $\displaystyle r_{gp} = max \cdot [0, r_{cu} + p \cdot (r - r_h - r_{cu})]$

# %%
# Calculating General Parter (GP) rate of return
# gp_return = max(0, 0.18*(0.2 - 0.1))
# gp_return

# Using Julia Programming language
# gp_return = max.(0, 0.18*(0.2 - 0.1))
# gp_return

# using R programming
gp_return <- max(0, 0.18*(0.2 - 0.1))
gp_return
# Out:
# [1] 0.018
