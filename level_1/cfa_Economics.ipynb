# %% [markdown]
# <a href="https://colab.research.google.com/github/1021114Carlos/cfa_practice/blob/main/level_1/cfa_Economics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Library Packages

# %%
import pandas as pd

# %% [markdown]
# *Herfindahl-Hirshmann Index*

# %%
# Concentration Ratios
concentration_ratios = (300 + 250 + 200 + 150)/1050
concentration_ratios
# Out:
# 0.8571428571428571

# %%
# Herfindahl-Hirshmann Index
hhi = (80/100)*0.8**2
hhi
# Out:
# 0.5120000000000001
