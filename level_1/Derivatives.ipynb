# %% [markdown]
# <a href="https://colab.research.google.com/github/1021114Carlos/cfa_practice/blob/main/level_1/Derivatives.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, Math, Latex

# %%
forward_price = display(Math(f"F_0 = S_0*(1 + r)^T"))
# Out:
# $\displaystyle F_0 = S_0*(1 + r)^T$
